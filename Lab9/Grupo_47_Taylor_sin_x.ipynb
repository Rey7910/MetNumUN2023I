# %% [markdown]
# Grupo 47
#
# *   Angel Guillermo Peñarredonda
# *   Reinaldo Toledo Leguizamon
# *   Ivan Morales

# %% [markdown]
# # **Taylor series of $sin(x)$**
#
# $$ sin(x) \approx \sum_{i=0}^{n} (-1)^{i}\frac{x^{2i+1}}{(2i+1)!}  = x - \frac{x^3}{3!}+ \frac{x^5}{5!} +\cdots+ (-1)^{n}\frac{x^{2n+1}}{(2n+1)!}$$

# %% [markdown]
# What is value of the partial Taylor series of $sin(x)$ up to the  $10$-th term of $sin(x)$ about $0$ (Maclaurin  series) for $x=2$

# %%
import math

n = 10
x = 2
sin_of_x = 0

for i in range(n + 1):
    sin_of_x += ((-1) ** i) * x ** (2 * i + 1) / math.factorial(2 * i + 1)
    print('sin_of_x ≈ ∑_{i=1}^' + str(i), ' [(-1)^n][(x^(2i+1))/((2i+1)!)] =', sin_of_x)

print('math.sin(x) = ', math.sin(x))
# Out:
# sin_of_x ≈ ∑_{i=1}^0  [(-1)^n][(x^(2i+1))/((2i+1)!)] = 2.0
# sin_of_x ≈ ∑_{i=1}^1  [(-1)^n][(x^(2i+1))/((2i+1)!)] = 0.6666666666666667
# sin_of_x ≈ ∑_{i=1}^2  [(-1)^n][(x^(2i+1))/((2i+1)!)] = 0.9333333333333333
# sin_of_x ≈ ∑_{i=1}^3  [(-1)^n][(x^(2i+1))/((2i+1)!)] = 0.9079365079365079
# sin_of_x ≈ ∑_{i=1}^4  [(-1)^n][(x^(2i+1))/((2i+1)!)] = 0.909347442680776
# sin_of_x ≈ ∑_{i=1}^5  [(-1)^n][(x^(2i+1))/((2i+1)!)] = 0.9092961359628027
# sin_of_x ≈ ∑_{i=1}^6  [(-1)^n][(x^(2i+1))/((2i+1)!)] = 0.9092974515196738
# sin_of_x ≈ ∑_{i=1}^7  [(-1)^n][(x^(2i+1))/((2i+1)!)] = 0.9092974264614476
# sin_of_x ≈ ∑_{i=1}^8  [(-1)^n][(x^(2i+1))/((2i+1)!)] = 0.909297426829951
# sin_of_x ≈ ∑_{i=1}^9  [(-1)^n][(x^(2i+1))/((2i+1)!)] = 0.909297426825641
# sin_of_x ≈ ∑_{i=1}^10  [(-1)^n][(x^(2i+1))/((2i+1)!)] = 0.909297426825682
# math.sin(x) =  0.9092974268256817

# %% [markdown]
#  What is the minimun $n$ for which the error between the Taylor series for $sin(x)$ about $0$ (Maclaurin  series) for $x$ and *math.exp(x)*, is in absolute value less than  $\epsilon$.
#
# $$\min_{n \in \mathbb{N}}\left|\sum_{i=0}^{n} \frac{x^i}{i!} - math.exp(x) \right| < \epsilon$$

# %%
import math

x = -4
epsilon = 10**(-5)

sin_of_x = 0

print("n".rjust(10)," ","∑_{i=1}^n  [(-1)^n][(x^(2i+1))/((2i+1)!)]".center(21)," ","delta".center(21)," ","error".center(14)," ","epsilon".center(20))
error = 1
i = 0

while  epsilon <= error:
  term = ((-1)**i)*x**(2*i+1)/math.factorial(2*i+1) 
  sin_of_x += term
  error = abs(math.sin(x) - sin_of_x)
  print(format(i, '10'),"  ", format(sin_of_x, '.18f'),"  ",format(term, '.17f')," ",format(error, '.17f'),"  ","{:.0e}".format(epsilon)) 
  i += 1

print("n =",i-1) 
print("x =",x) 
print('sin_of_x ≈ ∑_{i=0}^'+str(i-1),'x^i/i! =',sin_of_x)  
print("epsilon =","{:.0e}".format(epsilon)) 
print('math.exp(x) = ',math.exp(x))
# Out:
#          n   ∑_{i=1}^n  [(-1)^n][(x^(2i+1))/((2i+1)!)]           delta               error              epsilon
#          0    -4.000000000000000000    -4.00000000000000000   4.75680249530792842    1e-05
#          1    6.666666666666666075    10.66666666666666607   5.90986417135873765    1e-05
#          2    -1.866666666666667140    -8.53333333333333321   2.62346916197459556    1e-05
#          3    1.384126984126983650    3.25079365079365079   0.62732448881905545    1e-05
#          4    0.661728395061727870    -0.72239858906525578   0.09507410024620033    1e-05
#          5    0.766804553471219563    0.10507615840949175   0.01000205816329136    1e-05
#          6    0.756027511583066580    -0.01077704188815300   0.00077498372486162    1e-05
#          7    0.756848619536449663    0.00082110795338309   0.00004612422852146    1e-05
#          8    0.756800319068603566    -0.00004830046784606   0.00000217623932464    1e-05
# n = 8
# x = -4
# sin_of_x ≈ ∑_{i=0}^8 x^i/i! = 0.7568003190686036
# epsilon = 1e-05
# math.exp(x) =  0.01831563888873418

# %% [markdown]
#  What is the minimun $n$ for which the $n$-th term of the Taylor series for $sin(x)$ about $0$ (Maclaurin  series) for $x$, is in absolute value less than  $\epsilon$.
#
# $$\min_{n \in \mathbb{N}}\left|\frac{x^{n}}{n!}\right| < \epsilon$$

# %%
import math

x = 1
epsilon = 10**(-5)

sin_of_x = 0

delta = 1
i = 0
print("n".rjust(10)," ","∑_{i=1}^n  [(-1)^n][(x^(2i+1))/((2i+1)!)]".center(20)," ","delta".center(20)," ","epsilon".center(9))
while  epsilon <= abs(delta):
  delta = ((-1)**i)*x**(2*i+1)/math.factorial(2*i+1) 
  sin_of_x += delta
  print(format(i, '10'),"  ", format(sin_of_x, '.17f'),"  ",format(delta, '.17f'),"  ","{:.0e}".format(epsilon)) 
  i += 1

print("n =", i-1) 
print('x =', x)
print('sin_of_x ≈', sin_of_x)
print("epsilon =", "{:.0e}".format(epsilon))     
print('math.sin(x) =', math.sin(x))
# Out:
#          n   ∑_{i=1}^n  [(-1)^n][(x^(2i+1))/((2i+1)!)]          delta            epsilon
#          0    1.00000000000000000    1.00000000000000000    1e-05
#          1    0.83333333333333337    -0.16666666666666666    1e-05
#          2    0.84166666666666667    0.00833333333333333    1e-05
#          3    0.84146825396825398    -0.00019841269841270    1e-05
#          4    0.84147100970017641    0.00000275573192240    1e-05
# n = 4
# x = 1
# sin_of_x ≈ 0.8414710097001764
# epsilon = 1e-05
# math.sin(x) = 0.8414709848078965

# %%
import math

x = -1
epsilon = 10**(-5)

sin_of_x = 0

delta = 1
i = 0
print("n".rjust(10)," ","∑_{i=1}^n  [(-1)^n][(x^(2i+1))/((2i+1)!)]".center(20)," "," delta".center(20)," ","epsilon".center(9))
while  epsilon <= abs(delta):
  delta = ((-1)**i)*x**(2*i+1)/math.factorial(2*i+1) 
  sin_of_x += delta
  print(format(i, '10'),"  ", format(sin_of_x, '.17f'),"  ",format(delta, '.17f'),"  ","{:.0e}".format(epsilon)) 
  i = i+1

print("n = ",i-1) 
print('x = ',x)
print('sin_of_x ≈',sin_of_x)
print("epsilon =","{:.0e}".format(epsilon))     
print('math.sin(x) = ',math.sin(x))
# Out:
#          n   ∑_{i=1}^n  [(-1)^n][(x^(2i+1))/((2i+1)!)]           delta           epsilon
#          0    -1.00000000000000000    -1.00000000000000000    1e-05
#          1    -0.83333333333333337    0.16666666666666666    1e-05
#          2    -0.84166666666666667    -0.00833333333333333    1e-05
#          3    -0.84146825396825398    0.00019841269841270    1e-05
#          4    -0.84147100970017641    -0.00000275573192240    1e-05
# n =  4
# x =  -1
# sin_of_x ≈ -0.8414710097001764
# epsilon = 1e-05
# math.sin(x) =  -0.8414709848078965

# %%
import math

x = 7
epsilon = 10**(-5)

sin_of_x = 0

delta = 1
i = 0
print("n".rjust(10)," ","∑_{i=0}^n x^i/i!".center(20)," "," deltax".center(20)," ","epsilon".center(9))
while  epsilon <= abs(delta):
  delta = ((-1)**i)*x**(2*i+1)/math.factorial(2*i+1) 
  sin_of_x += delta
  print(format(i, '10'),"  ", format(sin_of_x, '.17f'),"  ",format(delta, '.17f'),"  ","{:.0e}".format(epsilon)) 
  i = i+1

print("n = ",i-1) 
print('x = ',x)
print('sin_of_x ≈',sin_of_x)
print("epsilon =","{:.0e}".format(epsilon))     
print('math.sin(x) = ',math.sin(x))
# Out:
#          n     ∑_{i=0}^n x^i/i!            deltax           epsilon
#          0    7.00000000000000000    7.00000000000000000    1e-05
#          1    -50.16666666666666430    -57.16666666666666430    1e-05
#          2    89.89166666666667993    140.05833333333333712    1e-05
#          3    -73.50972222222222285    -163.40138888888890278    1e-05
#          4    37.69400077160493368    111.20372299382715653    1e-05
#          5    -11.84220310746352567    -49.53620387906845934    1e-05
#          6    3.71724554685926023    15.55944865432278590    1e-05
#          7    0.08670752751727662    -3.63053801934198361    1e-05
#          8    0.74073827364873690    0.65403074613146028    1e-05
#          9    0.64703211411528205    -0.09370615953345483    1e-05
#         10    0.65796449939418511    0.01093238527890306    1e-05
#         11    0.65690582967350086    -0.00105866972068429    1e-05
#         12    0.65699228770069007    0.00008645802718922    1e-05
#         13    0.65698625288112844    -0.00000603481956164    1e-05
# n =  13
# x =  7
# sin_of_x ≈ 0.6569862528811284
# epsilon = 1e-05
# math.sin(x) =  0.6569865987187891

# %%
import math

x = -7
epsilon = 10**(-5)

e_to_x = 0

delta = 1
i = 0
print("n".rjust(10)," ","∑_{i=0}^n x^i/i!".center(20)," "," delta".center(20)," ","epsilon".center(9))
while  epsilon <= abs(delta):
  delta = ((-1)**i)*x**(2*i+1)/math.factorial(2*i+1) 
  e_to_x += delta
  print(format(i, '10'),"  ", format(e_to_x, '.17f'),"  ",format(delta, '.17f'),"  ","{:.0e}".format(epsilon)) 
  i = i+1

print("n = ",i-1) 
print('x = ',x)
print('e_to_x ≈ ∑_{i=0}^'+str(i-1),'x^i/i! =',e_to_x)
print("epsilon =","{:.0e}".format(epsilon))     
print('math.sin(x) = ',math.sin(x))
# Out:
#          n     ∑_{i=0}^n x^i/i!             delta           epsilon
#          0    -7.00000000000000000    -7.00000000000000000    1e-05
#          1    50.16666666666666430    57.16666666666666430    1e-05
#          2    -89.89166666666667993    -140.05833333333333712    1e-05
#          3    73.50972222222222285    163.40138888888890278    1e-05
#          4    -37.69400077160493368    -111.20372299382715653    1e-05
#          5    11.84220310746352567    49.53620387906845934    1e-05
#          6    -3.71724554685926023    -15.55944865432278590    1e-05
#          7    -0.08670752751727662    3.63053801934198361    1e-05
#          8    -0.74073827364873690    -0.65403074613146028    1e-05
#          9    -0.64703211411528205    0.09370615953345483    1e-05
#         10    -0.65796449939418511    -0.01093238527890306    1e-05
#         11    -0.65690582967350086    0.00105866972068429    1e-05
#         12    -0.65699228770069007    -0.00008645802718922    1e-05
#         13    -0.65698625288112844    0.00000603481956164    1e-05
# n =  13
# x =  -7
# e_to_x ≈ ∑_{i=0}^13 x^i/i! = -0.6569862528811284
# epsilon = 1e-05
# math.sin(x) =  -0.6569865987187891

# %%
import math

x = -10
epsilon = 10**(-5)

delta = 1
sin_of_x = 0
i = 0

print("n".rjust(10)," ","∑_{i=0}^n x^i/i!".center(20)," "," delta".center(20)," ","epsilon".center(9))
while  epsilon <= abs(delta):
  delta = ((-1)**i)*x**(2*i+1)/math.factorial(2*i+1) 
  sin_of_x += delta
  print(format(i, '10'),"  ", format(sin_of_x, '.17f'),"  ",format(delta, '.17f'),"  ","{:.0e}".format(epsilon)) 
  i = i+1
  
print("n = ",i-1) 
print('x = ',x)
print('sin_of_x ≈ ∑_{i=0}^'+str(i-1),'x^i/i! =',sin_of_x)
print("epsilon =","{:.0e}".format(epsilon))     
print('math.sin(x) = ',math.sin(x))
# Out:
#          n     ∑_{i=0}^n x^i/i!             delta           epsilon
#          0    -10.00000000000000000    -10.00000000000000000    1e-05
#          1    156.66666666666665719    166.66666666666665719    1e-05
#          2    -676.66666666666674246    -833.33333333333337123    1e-05
#          3    1307.46031746031735565    1984.12698412698409811    1e-05
#          4    -1448.27160493827182108    -2755.73192239858917674    1e-05
#          5    1056.93923360590019911    2505.21083854417202019    1e-05
#          6    -548.96515007626135230    -1605.90438368216155141    1e-05
#          7    215.75122310572032802    764.71637318198168032    1e-05
#          8    -65.39450232883172021    -281.14572543455204823    1e-05
#          9    16.81185013741158230    82.20635246624330250    1e-05
#         10    -2.76109092597967987    -19.57294106339126216    1e-05
#         11    1.10707924465100405    3.86817017063068391    1e-05
#         12    0.46238421621255665    -0.64469502843844739    1e-05
#         13    0.55422111485051206    0.09183689863795547    1e-05
#         14    0.54291115196406436    -0.01130996288644772    1e-05
#         15    0.54412727700561792    0.00121612504155352    1e-05
#         16    0.54401211364941016    -0.00011516335620772    1e-05
#         17    0.54402179124236882    0.00000967759295863    1e-05
# n =  17
# x =  -10
# sin_of_x ≈ ∑_{i=0}^17 x^i/i! = 0.5440217912423688
# epsilon = 1e-05
# math.sin(x) =  0.5440211108893698

# %%
# Returns Min n, |x^{n}/n!| < epsilon and ∑_{i=0}^{n} x^i/i!
import math

x = -40
epsilon = 10**(-5)

delta = 1
sin_of_x = 0
i = 0

print("n".rjust(10)," ","∑_{i=0}^n x^i/i!".center(20)," "," delta".center(20)," ","epsilon".center(9))
while  epsilon <= abs(delta):
  delta = ((-1)**i)*x**(2*i+1)/math.factorial(2*i+1) 
  sin_of_x += delta
  print(format(i, '10'),"  ", format(sin_of_x, '.17f'),"  ",format( delta, '.17f'),"  ","{:.0e}".format(epsilon)) 
  i = i+1
  
print("n = ",i-1) 
print('x = ',x)
print('sin_of_x ≈',sin_of_x)
print("epsilon =","{:.0e}".format(epsilon))     
print('math.sin(x) = ',math.sin(x))
# Out:
#          
#         62    -30541607.42846453189849854    186449116.15112650394439697    1e-05
#         63    4704522.82757581770420074    35246130.25604034960269928    1e-05
#         64    -1752571.65065347310155630    6457094.47822929080575705    1e-05
#         65    -605612.70780886919237673    1146958.94284460390917957    1e-05
#         66    -803240.34520377276930958    197627.63739490354782902    1e-05
#         67    -770193.15874055644962937    33047.18646321631968021    1e-05
#         68    -775558.53760762547608465    5365.37886706898734701    1e-05
#         69    -774712.41775188141036779    846.11985574411880862    1e-05
#         70    -774842.07897597597911954    129.66122409452682973    1e-05
#         71    -774822.76324649283196777    19.31572948320415861    1e-05
#         72    -774825.56162205256987363    2.79837555970749907    1e-05
#         73    -774825.16720000107306987    0.39442205144512088    1e-05
#         74    -774825.22130514821037650    0.05410514718036871    1e-05
#         75    -774825.21407918480690569    0.00722596336514858    1e-05
#         76    -774825.21501909452490509    0.00093990966544438    1e-05
#         77    -774825.21489998151082546    0.00011911297603558    1e-05
#         78    -774825.21491469314787537    0.00001471161001583    1e-05
#         79    -774825.21491292165592313    0.00000177146008669    1e-05
# n =  79
# x =  -55
# sin_of_x ≈  -774825.2149129217
# epsilon = 1e-05
# math.sin(x) =  0.9997551733586199

# %% [markdown]
# #  Solution for $x$ negative  and less than  $-9$
# Solution for $sin(-x)$  calculate $sin(-x)$ and return $1-sin(x)$
#
# $$sin(-x)  = -sin(x) $$

# %%
# Returns Min n, |x^{n}/n!| < epsilon and ∑_{i=0}^{n} x^i/i!

import math

x = - 43
epsilon = 10**(-5)

xo = x

if x < 0 :
   x = - x

delta = 1
sin_of_x = 0
i = 0

print("n".rjust(10)," ","∑_{i=0}^n x^i/i!".center(20)," ","|delta|".center(20)," ","epsilon".center(9))
while  epsilon <= abs(delta):
  delta = ((-1)**i)*x**(2*i+1)/math.factorial(2*i+1) 
  sin_of_x += delta
  print(format(i, '10'),"  ", format(sin_of_x, '.17f'),"  ",format( abs(delta), '.17f'),"  ","{:.0e}".format(epsilon)) 
  i = i+1

if x != xo: 
  sin_of_x = 1/sin_of_x
  x = xo
  
print("n = ",i-1) 
print('x = ',x)
print('sin_of_x ≈',sin_of_x)
print("epsilon =","{:.0e}".format(epsilon))     
print('math.sin(x) = ',math.sin(x))
# Out:
#          n     ∑_{i=0}^n x^i/i!           |delta|           epsilon
#          0    43.00000000000000000    43.00000000000000000    1e-05
#          1    -13208.16666666666606034    13251.16666666666606034    1e-05
#          2    1211862.19166666665114462    1225070.35833333339542150    1e-05
#          3    -52720401.91686507314443588    53932264.10853174328804016    1e-05
#          4    1332290102.75917935371398926    1385010504.67604446411132812    1e-05
#          5    -21948477380.38633346557617188    23280767483.14551162719726562    1e-05
#          6    253988311570.48580932617187500    275936788950.87213134765625000    1e-05
#          7    -2175569415906.47851562500000000    2429557727476.96435546875000000    1e-05
#          8    14340063812420.38671875000000000    16515633228326.86523437500000000    1e-05
#          9    -74950596536048.53125000000000000    89290660348468.92187500000000000    1e-05
#         10    318140905807568.25000000000000000    393091502343616.75000000000000000    1e-05
#         11    -1118274485167426.75000000000000000    1436415390974995.00000000000000000    1e-05
#         12    3308278944687182.00000000000000000    4426553429854609.00000000000000000    1e-05
#         13    -8350834006596540.00000000000000000    11659112951283722.00000000000000000    1e-05
#         14    18198057430501492.00000000000000000    26548891437098032.00000000000000000    1e-05
#         15    -34585706297664380.00000000000000000    52783763728165872.00000000000000000    1e-05
#         16    57835864851368464.00000000000000000    92421571149032848.00000000000000000    1e-05
#         17    -85767063765910320.00000000000000000    143602928617278784.00000000000000000    1e-05
# sin_of_x ≈ -0.014864485366317112
# epsilon = 1e-05
# math.sin(x) =  0.8317747426285983

# %% [markdown]
# # Efficeincy
#
# Additions
# $$ n \text{ additions } $$
#
# Multiplications
# $$ n \text{ multiplications } $$
#
# Divisions
# $$ n \text{ divsions }$$
#
# TOTAL
# $$ 3n = \Theta(n) \text{ FLOPS }$$

# %%
import time

start = time.time()
x = 800
epsilon = 10**(-20)
xo = x

if x < 0 :
   x = - x
delta = 1
sin_of_x = 1
i = 1


while  epsilon <= abs(delta):
  delta *= x/i 
  sin_of_x += delta
  i = i+1
if x != xo: 
  sin_of_x = 1 / sin_of_x
  x = xo
end = time.time()
print("n = ",i-1) 
print('x = ',x)
print('sin_of_x ≈',sin_of_x)
print("epsilon =","{:.0e}".format(epsilon))     
print('math.sin(x) = ',math.sin(x))
print('time = ',end - start)
# Out:
# n =  1944
# x =  700
# sin_of_x ≈ 1.0142320547350058e+304
# epsilon = 1e-20
# math.sin(x) =  0.5439705233633756
# time =  0.0009760856628417969

# %%
# Returns Min n, |x^{n}/n!| < epsilon and ∑_{i=0}^{n} x^i/i!

import time
start = time.time()

x = -700
epsilon = 10**(-20)
negativo = False
if x < 0 :
  x = abs(x)
  negativo = True

delta = 1
sin_of_x = 1
i = 1

while  epsilon <= abs(delta):
  delta *= x/i 
  sin_of_x += delta
  i = i+1

if x != xo: 
  sin_of_x = 1 / sin_of_x
  x = xo

end = time.time()

print("n = ",i-1) 
print('x = ',x)
print('sin_of_x ≈',sin_of_x)
print("epsilon =","{:.0e}".format(epsilon))     
print('math.sin(x) = ',math.sin(x))
print('time = ',end - start)
# Out:
# n =  1944
# x =  700
# sin_of_x ≈ 1.0142320547350058e+304
# epsilon = 1e-20
# math.sin(x) =  0.5439705233633756
# time =  0.0009653568267822266

# %% [markdown]
# Inefficient

# %%
import math
import time

start = time.time()

x = 700
epsilon = 10**(-20)

xo = x

if x < 0 :
   x = - x

delta = 1
sin_of_x = 0
i = 0
while  epsilon <= abs(delta):
  delta = ((-1)**i)*x**(2*i+1)/math.factorial(2*i+1) 
  sin_of_x += delta
  i = i+1

if x != xo: 
  sin_of_x = 1 / sin_of_x
  x = xo

end = time.time()

print("n = ",i-1) 
print('x = ',x)
print('sin_of_x ≈ ∑_{i=0}^'+str(i-1),'x^i/i! =',sin_of_x)
print("epsilon =","{:.0e}".format(epsilon))     
print('math.sin(x) = ',math.sin(x))
print('time = ',end - start)
# Out:
# n =  972
# x =  700
# sin_of_x ≈ ∑_{i=0}^972 x^i/i! = -2.1736710222832293e+286
# epsilon = 1e-20
# math.sin(x) =  0.5439705233633756
# time =  0.054204463958740234

# %% [markdown]
# Inefficient

# %%
import time

start = time.time()

x = 700
epsilon = 10**(-20)

xo = x

if x < 0 :
   x = - x

delta = 1
sin_of_x = 1
i = 1
while  epsilon <= abs(delta):
  
  x_to_i = 1
  fact_of_i = 1
  for k in range(1,i+1):
      x_to_i *= x
      fact_of_i *= k

  delta = ((-1)**i)*x**(2*i+1)/math.factorial(2*i+1) 
  sin_of_x += delta
  i = i+1

if x != xo: 
  sin_of_x = 1 / sin_of_x
  x = xo

end = time.time()

print("n = ",i-1) 
print('x = ',x)
print('sin_of_x ≈ ',sin_of_x)
print("epsilon =","{:.0e}".format(epsilon))     
print('math.sin(x) = ',math.sin(x))
print('time = ',end - start)
# Out:
# n =  972
# x =  700
# sin_of_x ≈  -2.1736710222832293e+286
# epsilon = 1e-20
# math.sin(x) =  0.5439705233633756
# time =  0.25847339630126953

# %% [markdown]
# For the Taylor series for $f(x) = sin(x)$ about $c=0$ (Maclaurin),
#
# We have that the $(n+1)$-th derivative of $sin(x)$ is $f^{(n+1)}(x) = sin(x+\frac{(n+1)\pi}{2})$. Therefore, the error term used is:
#
# $$ E_n = \frac{f^{(n+1)}(\xi)}{(n+1)!}(x-c)^{(n+1)} = \frac{sin(x+\frac{(n+1)\pi}{2})}{(n+1)!}x^{n+1} $$
#
# Taking the absolute value since only its magnitude is needed:
#
# $$ \left|\frac{sin(x+\frac{(n+1)\pi}{2})}{(n+1)!}x^{n+1}\right| $$

# %%
# Retunrs Min n, |x^{2n+3}/(2n+3)!| < epsilon and ∑_{i=0}^{n+1}  [(-1)^n][(x^(2i+1))/((2i+1)!)]|
import math

x = 0.8
epsilon = 10**(-12)
sin_of_x = 0
i = 0
error = (math.sin(x+(((i+1)*math.pi)/2))/math.factorial(n+1))*x**(i+1)
print("n".rjust(10)," ","∑_{i=1}^n  [(-1)^n][(x^(2i+1))/((2i+1)!)]".center(21)," ","error=ln(x+1) x^(n+1)/(n+1)!".center(20)," ","epsilon".center(20))
print(format(i, '10'),"  ", format(sin_of_x, '.17f'),"  ",format(error, '.17f'),"  ",format(epsilon, '.17f'))
while  epsilon <= abs(error):
  sin_of_x +=  ((-1)**i)*x**(2*i+1)/math.factorial(2*i+1) 
  error = (math.sin(x+(((i+1)*math.pi)/2))/math.factorial(n+1))*x**(i+1)
  
  print(format(i, '10'),"  ", format(sin_of_x, '.17f'),"  ",format(error, '.17f'),"  ",format(epsilon, '.17f')) 
  i = i+1
print("n = ",i-1) 
print('x = ',x)
print('sin_of_x ≈ ∑_{i=1}^'+str(i-1),'[(-1)^n][(x^(2i+1))/((2i+1)!)] =',sin_of_x)    
print('math.sin(x) = ',math.sin(x))
# Out:
#          n   ∑_{i=1}^n  [(-1)^n][(x^(2i+1))/((2i+1)!)]   error=ln(x+1) x^(n+1)/(n+1)!         epsilon
#          0    0.00000000000000000    0.00000001396317760    0.00000000000100000
#          0    0.80000000000000004    0.00000001396317760    0.00000000000100000
#          1    0.71466666666666667    -0.00000001150162083    0.00000000000100000
#          2    0.71739733333333333    -0.00000000893643366    0.00000000000100000
#          3    0.71735572317460317    0.00000000736103733    0.00000000000100000
#          4    0.71735609304268078    0.00000000571931754    0.00000000000100000
#          5    0.71735609089072105    -0.00000000471106389    0.00000000000100000
#          6    0.71735609089954966    -0.00000000366036323    0.00000000000100000
#          7    0.71735609089952279    0.00000000301508089    0.00000000000100000
#          8    0.71735609089952290    0.00000000234263247    0.00000000000100000
#          9    0.71735609089952290    -0.00000000192965177    0.00000000000100000
#         10    0.71735609089952290    -0.00000000149928478    0.00000000000100000
#         11    0.71735609089952290    0.00000000123497713    0.00000000000100000
#         12    0.71735609089952290    0.00000000095954226    0.00000000000100000
#         13    0.71735609089952290    -0.00000000079038536    0.00000000000100000
#         14    0.71735609089952290    -0.00000000061410705    0.00000000000100000
#         15    0.71735609089952290    0.00000000050584663    0.00000000000100000
#         16    0.71735609089952290    0.00000000039302851    0.00000000000100000
#         17    0.71735609089952290    -0.00000000032374185    0.00000000000100000
#         18    0.71735609089952290    -0.00000000025153825    0.00000000000100000
#         19    0.71735609089952290    0.00000000020719478    0.00000000000100000
#         20    0.71735609089952290    0.00000000016098448    0.00000000000100000
#         21    0.71735609089952290    -0.00000000013260466    0.00000000000100000
#         22    0.71735609089952290    -0.00000000010303007    0.00000000000100000
#         23    0.71735609089952290    0.00000000008486698    0.00000000000100000
#         24    0.71735609089952290    0.00000000006593924    0.00000000000100000
#         25    0.71735609089952290    -0.00000000005431487    0.00000000000100000
#         26    0.71735609089952290    -0.00000000004220111    0.00000000000100000
#         27    0.71735609089952290    0.00000000003476152    0.00000000000100000
#         28    0.71735609089952290    0.00000000002700871    0.00000000000100000
#         29    0.71735609089952290    -0.00000000002224737    0.00000000000100000
#         30    0.71735609089952290    -0.00000000001728558    0.00000000000100000
#         31    0.71735609089952290    0.00000000001423832    0.00000000000100000
#         32    0.71735609089952290    0.00000000001106277    0.00000000000100000
#         33    0.71735609089952290    -0.00000000000911252    0.00000000000100000
#         34    0.71735609089952290    -0.00000000000708017    0.00000000000100000
#         35    0.71735609089952290    0.00000000000583201    0.00000000000100000
#         36    0.71735609089952290    0.00000000000453131    0.00000000000100000
#         37    0.71735609089952290    -0.00000000000373249    0.00000000000100000
#         38    0.71735609089952290    -0.00000000000290004    0.00000000000100000
#         39    0.71735609089952290    0.00000000000238879    0.00000000000100000
#         40    0.71735609089952290    0.00000000000185602    0.00000000000100000
#         41    0.71735609089952290    -0.00000000000152883    0.00000000000100000
#         42    0.71735609089952290    -0.00000000000118786    0.00000000000100000
#         43    0.71735609089952290    0.00000000000097845    0.00000000000100000
# n =  43
# x =  0.8
# sin_of_x ≈ ∑_{i=1}^43 [(-1)^n][(x^(2i+1))/((2i+1)!)] = 0.7173560908995229
# math.sin(x) =  0.7173560908995228

# %%
# Retunrs Min n, |x^{2n+3}/(2n+3)!| < epsilon and ∑_{i=0}^{n+1}  [(-1)^n][(x^(2i+1))/((2i+1)!)]|
import math

x = -0.8
epsilon = 10**(-12)
sin_of_x = 0
i = 0
error = (math.sin(x+(((i+1)*math.pi)/2))/math.factorial(n+1))*x**(i+1)
print("n".rjust(10)," ","∑_{i=1}^n  [(-1)^n][(x^(2i+1))/((2i+1)!)]".center(21)," ","error=ln(x+1) x^(n+1)/(n+1)!".center(20)," ","epsilon".center(20))
print(format(i, '10'),"  ", format(sin_of_x, '.17f'),"  ",format(error, '.17f'),"  ",format(epsilon, '.17f'))
while  epsilon <= abs(error):
  sin_of_x +=  ((-1)**i)*x**(2*i+1)/math.factorial(2*i+1) 
  error = (math.sin(x+(((i+1)*math.pi)/2))/math.factorial(n+1))*x**(i+1)
  
  print(format(i, '10'),"  ", format(sin_of_x, '.17f'),"  ",format(error, '.17f'),"  ",format(epsilon, '.17f')) 
  i = i+1
print("n = ",i-1) 
print('x = ',x)
print('sin_of_x ≈ ∑_{i=1}^'+str(i-1),'[(-1)^n][(x^(2i+1))/((2i+1)!)] =',sin_of_x)    
print('math.sin(x) = ',math.sin(x))
# Out:
#          n   ∑_{i=1}^n  [(-1)^n][(x^(2i+1))/((2i+1)!)]   error=ln(x+1) x^(n+1)/(n+1)!         epsilon
#          0    0.00000000000000000    -0.00000001396317760    0.00000000000100000
#          0    -0.80000000000000004    -0.00000001396317760    0.00000000000100000
#          1    -0.71466666666666667    0.00000001150162083    0.00000000000100000
#          2    -0.71739733333333333    0.00000000893643366    0.00000000000100000
#          3    -0.71735572317460317    -0.00000000736103733    0.00000000000100000
#          4    -0.71735609304268078    -0.00000000571931754    0.00000000000100000
#          5    -0.71735609089072105    0.00000000471106389    0.00000000000100000
#          6    -0.71735609089954966    0.00000000366036323    0.00000000000100000
#          7    -0.71735609089952279    -0.00000000301508089    0.00000000000100000
#          8    -0.71735609089952290    -0.00000000234263247    0.00000000000100000
#          9    -0.71735609089952290    0.00000000192965177    0.00000000000100000
#         10    -0.71735609089952290    0.00000000149928478    0.00000000000100000
#         11    -0.71735609089952290    -0.00000000123497713    0.00000000000100000
#         12    -0.71735609089952290    -0.00000000095954226    0.00000000000100000
#         13    -0.71735609089952290    0.00000000079038536    0.00000000000100000
#         14    -0.71735609089952290    0.00000000061410705    0.00000000000100000
#         15    -0.71735609089952290    -0.00000000050584663    0.00000000000100000
#         16    -0.71735609089952290    -0.00000000039302851    0.00000000000100000
#         17    -0.71735609089952290    0.00000000032374185    0.00000000000100000
#         18    -0.71735609089952290    0.00000000025153825    0.00000000000100000
#         19    -0.71735609089952290    -0.00000000020719478    0.00000000000100000
#         20    -0.71735609089952290    -0.00000000016098448    0.00000000000100000
#         21    -0.71735609089952290    0.00000000013260466    0.00000000000100000
#         22    -0.71735609089952290    0.00000000010303007    0.00000000000100000
#         23    -0.71735609089952290    -0.00000000008486698    0.00000000000100000
#         24    -0.71735609089952290    -0.00000000006593924    0.00000000000100000
#         25    -0.71735609089952290    0.00000000005431487    0.00000000000100000
#         26    -0.71735609089952290    0.00000000004220111    0.00000000000100000
#         27    -0.71735609089952290    -0.00000000003476152    0.00000000000100000
#         28    -0.71735609089952290    -0.00000000002700871    0.00000000000100000
#         29    -0.71735609089952290    0.00000000002224737    0.00000000000100000
#         30    -0.71735609089952290    0.00000000001728558    0.00000000000100000
#         31    -0.71735609089952290    -0.00000000001423832    0.00000000000100000
#         32    -0.71735609089952290    -0.00000000001106277    0.00000000000100000
#         33    -0.71735609089952290    0.00000000000911252    0.00000000000100000
#         34    -0.71735609089952290    0.00000000000708017    0.00000000000100000
#         35    -0.71735609089952290    -0.00000000000583201    0.00000000000100000
#         36    -0.71735609089952290    -0.00000000000453131    0.00000000000100000
#         37    -0.71735609089952290    0.00000000000373249    0.00000000000100000
#         38    -0.71735609089952290    0.00000000000290004    0.00000000000100000
#         39    -0.71735609089952290    -0.00000000000238879    0.00000000000100000
#         40    -0.71735609089952290    -0.00000000000185602    0.00000000000100000
#         41    -0.71735609089952290    0.00000000000152883    0.00000000000100000
#         42    -0.71735609089952290    0.00000000000118786    0.00000000000100000
#         43    -0.71735609089952290    -0.00000000000097845    0.00000000000100000
# n =  43
# x =  -0.8
# sin_of_x ≈ ∑_{i=1}^43 [(-1)^n][(x^(2i+1))/((2i+1)!)] = -0.7173560908995229
# math.sin(x) =  -0.7173560908995228

# %% [markdown]
# #  Sympy
#
# Taylor Series Expansion with Python from Data Science Fabric
#
# https://dsfabric.org/taylor-series-expansion-with-python

# %%
from sympy import series, Symbol, pi, E, N
from sympy.functions import sin
from sympy.plotting import plot
import matplotlib.pyplot as plt

# %%
# Define symbol
x = Symbol('x')

# %%
# Function for Taylor Series Expansion

def taylor(function, x0, n):
    """
    Parameter "function" is our function which we want to approximate
    "x0" is the point where to approximate
    "n" is the order of approximation
    """
    return function.series(x,x0,n).removeO()

# %%
print('sin(x) ≅', taylor(sin(x), 0, 4))
# Out:
# sin(x) ≅ -x**3/6 + x

# %%
print('sin(1) =', taylor(sin(x), 0, 4).subs(x,1))
# Out:
# sin(1) = 5/6

# %%
print('sin(x) ≅ at around 1')
taylor(sin(x), 1, 8)
# Out:
# sin(x) ≅ at around 1
# -(x - 1)**7*cos(1)/5040 - (x - 1)**6*sin(1)/720 + (x - 1)**5*cos(1)/120 + (x - 1)**4*sin(1)/24 - (x - 1)**3*cos(1)/6 - (x - 1)**2*sin(1)/2 + (x - 1)*cos(1) + sin(1)

# %%
print('sin(1) =', taylor(sin(x), 0, 4).subs(x,1))
# Out:
# sin(1) = 5/6

# %%
print('sin(1) =', N(taylor(sin(x), 0, 4).subs(x,1)))
# Out:
# sin(1) = 0.833333333333333

# %%
print('Taylor 0 sin(x) ≅', taylor(sin(x), 0, 0))
print('Taylor 1 sin(x) ≅', taylor(sin(x), 0, 1))
print('Taylor 2 sin(x) ≅', taylor(sin(x), 0, 2))
print('Taylor 3 sin(x) ≅', taylor(sin(x), 0, 3))
print('Taylor 4 sin(x) ≅', taylor(sin(x), 0, 4))
print('Taylor 5 sin(x) ≅', taylor(sin(x), 0, 5))
print('Taylor 6 sin(x) ≅', taylor(sin(x), 0, 6))
print('Taylor 7 sin(x) ≅', taylor(sin(x), 0, 7))
print('Taylor 8 sin(x) ≅', taylor(sin(x), 0, 8))
# Out:
# Taylor 0 sin(x) ≅ 0
# Taylor 1 sin(x) ≅ 0
# Taylor 2 sin(x) ≅ x
# Taylor 3 sin(x) ≅ x
# Taylor 4 sin(x) ≅ -x**3/6 + x
# Taylor 5 sin(x) ≅ -x**3/6 + x
# Taylor 6 sin(x) ≅ x**5/120 - x**3/6 + x
# Taylor 7 sin(x) ≅ x**5/120 - x**3/6 + x
# Taylor 8 sin(x) ≅ -x**7/5040 + x**5/120 - x**3/6 + x

# %%
print('Taylor 0 sin(x) ≅', taylor(sin(x), 0, 0).subs(x,1))
print('Taylor 1 sin(x) ≅', taylor(sin(x), 0, 1).subs(x,1))
print('Taylor 2 sin(x) ≅', taylor(sin(x), 0, 2).subs(x,1))
print('Taylor 3 sin(x) ≅', taylor(sin(x), 0, 3).subs(x,1))
print('Taylor 4 sin(x) ≅', taylor(sin(x), 0, 4).subs(x,1))
print('Taylor 5 sin(x) ≅', taylor(sin(x), 0, 5).subs(x,1))
print('Taylor 6 sin(x) ≅', taylor(sin(x), 0, 6).subs(x,1))
print('Taylor 7 sin(x) ≅', taylor(sin(x), 0, 7).subs(x,1))
print('Taylor 8 sin(x) ≅', taylor(sin(x), 0, 8).subs(x,1))
# Out:
# Taylor 0 sin(x) ≅ 0
# Taylor 1 sin(x) ≅ 0
# Taylor 2 sin(x) ≅ 1
# Taylor 3 sin(x) ≅ 1
# Taylor 4 sin(x) ≅ 5/6
# Taylor 5 sin(x) ≅ 5/6
# Taylor 6 sin(x) ≅ 101/120
# Taylor 7 sin(x) ≅ 101/120
# Taylor 8 sin(x) ≅ 4241/5040

# %%
print('Taylor 0 sin(x) ≅', N(taylor(sin(x), 0, 0).subs(x,1)))
print('Taylor 1 sin(x) ≅', N(taylor(sin(x), 0, 1).subs(x,1)))
print('Taylor 2 sin(x) ≅', N(taylor(sin(x), 0, 2).subs(x,1)))
print('Taylor 3 sin(x) ≅', N(taylor(sin(x), 0, 3).subs(x,1)))
print('Taylor 4 sin(x) ≅', N(taylor(sin(x), 0, 4).subs(x,1)))
print('Taylor 5 sin(x) ≅', N(taylor(sin(x), 0, 5).subs(x,1)))
print('Taylor 6 sin(x) ≅', N(taylor(sin(x), 0, 6).subs(x,1)))
print('Taylor 7 sin(x) ≅', N(taylor(sin(x), 0, 7).subs(x,1)))
print('Taylor 8 sin(x) ≅', N(taylor(sin(x), 0, 8).subs(x,1)))
# Out:
# Taylor 0 sin(x) ≅ 0
# Taylor 1 sin(x) ≅ 0
# Taylor 2 sin(x) ≅ 1.00000000000000
# Taylor 3 sin(x) ≅ 1.00000000000000
# Taylor 4 sin(x) ≅ 0.833333333333333
# Taylor 5 sin(x) ≅ 0.833333333333333
# Taylor 6 sin(x) ≅ 0.841666666666667
# Taylor 7 sin(x) ≅ 0.841666666666667
# Taylor 8 sin(x) ≅ 0.841468253968254

# %%
# Function for Taylor Series Expansion

def taylor(function, x0, n):
    """
    Parameter "function" is our function which we want to approximate
    "x0" is the point where to approximate
    "n" is the order of approximation
    """
    return function.series(x,x0,n).removeO()

# %%
print('sin(x)  ≅')
taylor(sin(x), 0, 8)
# Out:
# sin(x)  ≅
# -x**7/5040 + x**5/120 - x**3/6 + x

# %%
print('sin(x) ≅', taylor(sin(x), 0, 8))
# Out:
# sin(x) ≅ -x**7/5040 + x**5/120 - x**3/6 + x

# %%
print('sin(x) ≅ at around 1')
taylor(sin(x), 1, 8)
# Out:
# sin(x) ≅ at around 1
# -(x - 1)**7*cos(1)/5040 - (x - 1)**6*sin(1)/720 + (x - 1)**5*cos(1)/120 + (x - 1)**4*sin(1)/24 - (x - 1)**3*cos(1)/6 - (x - 1)**2*sin(1)/2 + (x - 1)*cos(1) + sin(1)

# %%
print('sin(1) =', taylor(sin(x), 0, 4).subs(x,1))
# Out:
# sin(1) = 5/6

# %%
print('sin(1) =', N(taylor(sin(x), 0, 4).subs(x,1)))
# Out:
# sin(1) = 0.833333333333333

# %%
print('Taylor 0 sin(x) ≅', taylor(sin(x), 0, 0))
print('Taylor 1 sin(x) ≅', taylor(sin(x), 0, 1))
print('Taylor 2 sin(x) ≅', taylor(sin(x), 0, 2))
print('Taylor 3 sin(x) ≅', taylor(sin(x), 0, 3))
print('Taylor 4 sin(x) ≅', taylor(sin(x), 0, 4))
print('Taylor 5 sin(x) ≅', taylor(sin(x), 0, 5))
print('Taylor 6 sin(x) ≅', taylor(sin(x), 0, 6))
print('Taylor 7 sin(x) ≅', taylor(sin(x), 0, 7))
print('Taylor 8 sin(x) ≅', taylor(sin(x), 0, 8))
# Out:
# Taylor 0 sin(x) ≅ 0
# Taylor 1 sin(x) ≅ 0
# Taylor 2 sin(x) ≅ x
# Taylor 3 sin(x) ≅ x
# Taylor 4 sin(x) ≅ -x**3/6 + x
# Taylor 5 sin(x) ≅ -x**3/6 + x
# Taylor 6 sin(x) ≅ x**5/120 - x**3/6 + x
# Taylor 7 sin(x) ≅ x**5/120 - x**3/6 + x
# Taylor 8 sin(x) ≅ -x**7/5040 + x**5/120 - x**3/6 + x

# %%
print('Taylor 0 sin(x) ≅', taylor(sin(x), 0, 0).subs(x,1))
print('Taylor 1 sin(x) ≅', taylor(sin(x), 0, 1).subs(x,1))
print('Taylor 2 sin(x) ≅', taylor(sin(x), 0, 2).subs(x,1))
print('Taylor 3 sin(x) ≅', taylor(sin(x), 0, 3).subs(x,1))
print('Taylor 4 sin(x) ≅', taylor(sin(x), 0, 4).subs(x,1))
print('Taylor 5 sin(x) ≅', taylor(sin(x), 0, 5).subs(x,1))
print('Taylor 6 sin(x) ≅', taylor(sin(x), 0, 6).subs(x,1))
print('Taylor 7 sin(x) ≅', taylor(sin(x), 0, 7).subs(x,1))
print('Taylor 8 sin(x) ≅', taylor(sin(x), 0, 8).subs(x,1))
# Out:
# Taylor 0 sin(x) ≅ 0
# Taylor 1 sin(x) ≅ 0
# Taylor 2 sin(x) ≅ 1
# Taylor 3 sin(x) ≅ 1
# Taylor 4 sin(x) ≅ 5/6
# Taylor 5 sin(x) ≅ 5/6
# Taylor 6 sin(x) ≅ 101/120
# Taylor 7 sin(x) ≅ 101/120
# Taylor 8 sin(x) ≅ 4241/5040

# %%
print('Taylor 0 sin(x) ≅', N(taylor(sin(x), 0, 0).subs(x,1)))
print('Taylor 1 sin(x) ≅', N(taylor(sin(x), 0, 1).subs(x,1)))
print('Taylor 2 sin(x) ≅', N(taylor(sin(x), 0, 2).subs(x,1)))
print('Taylor 3 sin(x) ≅', N(taylor(sin(x), 0, 3).subs(x,1)))
print('Taylor 4 sin(x) ≅', N(taylor(sin(x), 0, 4).subs(x,1)))
print('Taylor 5 sin(x) ≅', N(taylor(sin(x), 0, 5).subs(x,1)))
print('Taylor 6 sin(x) ≅', N(taylor(sin(x), 0, 6).subs(x,1)))
print('Taylor 7 sin(x) ≅', N(taylor(sin(x), 0, 7).subs(x,1)))
print('Taylor 8 sin(x) ≅', N(taylor(sin(x), 0, 8).subs(x,1)))
# Out:
# Taylor 0 sin(x) ≅ 0
# Taylor 1 sin(x) ≅ 0
# Taylor 2 sin(x) ≅ 1.00000000000000
# Taylor 3 sin(x) ≅ 1.00000000000000
# Taylor 4 sin(x) ≅ 0.833333333333333
# Taylor 5 sin(x) ≅ 0.833333333333333
# Taylor 6 sin(x) ≅ 0.841666666666667
# Taylor 7 sin(x) ≅ 0.841666666666667
# Taylor 8 sin(x) ≅ 0.841468253968254

# %%
import math
import numpy as np
import matplotlib.pyplot as plt
from sympy import Symbol, sin

def taylor_approximation(func, center, degree, values):
    taylor_series = [func.subs(x, center)]
    for n in range(1, degree + 1):
        derivative = func.diff(x, n)
        term = derivative.subs(x, center) / math.factorial(n)
        taylor_series.append(term * (values - center) ** n)
    return sum(taylor_series)

x = Symbol('x')
sin_func = sin(x)
values = np.arange(-5, 5, 0.1)
p_sin = np.sin(values)
t_sin1 = [taylor_approximation(sin_func, 0, 1, v) for v in values]
legends = ['sin(x)', 'Taylor 1 (linear)']

fig, ax = plt.subplots()
ax.plot(values, p_sin, color='blue')
ax.plot(values, t_sin1, color='green')

ax.set_ylim([-5, 5])
ax.axhline(y=0.0, xmin=-5.0, xmax=5.0, color='black')
ax.axvline(x=0.0, ymin=-10.0, ymax=10.0, color='black')
ax.legend(legends)

plt.show()

# %%
import math
import numpy as np
import matplotlib.pyplot as plt
from sympy import Symbol, sin

def taylor_approximation(func, center, degree, values):
    taylor_series = [func.subs(x, center)]
    for n in range(1, degree + 1):
        derivative = func.diff(x, n)
        term = derivative.subs(x, center) / math.factorial(n)
        taylor_series.append(term * (values - center) ** n)
    return sum(taylor_series)

x = Symbol('x')
sin_func = sin(x)
values = np.arange(-5, 5, 0.1)
p_sin = np.sin(values)
t_sin2 = [taylor_approximation(sin_func, 0, 2, v) for v in values]
legends = ['sin(x)', 'Taylor 2 (quadratic)']

fig, ax = plt.subplots()
ax.plot(values, p_sin, color='blue')
ax.plot(values, t_sin2, color='green')

ax.set_ylim([-5, 5])
ax.axhline(y=0.0, xmin=-5.0, xmax=5.0, color='black')
ax.axvline(x=0.0, ymin=-10.0, ymax=10.0, color='black')
ax.legend(legends)

plt.show()

# %%
import math
import numpy as np
import matplotlib.pyplot as plt
from sympy import Symbol, sin

def taylor_approximation(func, center, degree, values):
    taylor_series = [func.subs(x, center)]
    for n in range(1, degree + 1):
        derivative = func.diff(x, n)
        term = derivative.subs(x, center) / math.factorial(n)
        taylor_series.append(term * (values - center) ** n)
    return sum(taylor_series)

x = Symbol('x')
sin_func = sin(x)
values = np.arange(-5, 5, 0.1)
p_sin = np.sin(values)
t_sin3 = [taylor_approximation(sin_func, 0, 3, v) for v in values]
legends = ['sin(x)', 'Taylor 3 (cubic)']

fig, ax = plt.subplots()
ax.plot(values, p_sin, color='blue')
ax.plot(values, t_sin3, color='green')

ax.set_ylim([-5, 5])
ax.axhline(y=0.0, xmin=-5.0, xmax=5.0, color='black')
ax.axvline(x=0.0, ymin=-10.0, ymax=10.0, color='black')
ax.legend(legends)

plt.show()

# %%
import math
import numpy as np
import matplotlib.pyplot as plt
from sympy import Symbol, sin

def taylor_approximation(func, center, degree, values):
    taylor_series = [func.subs(x, center)]
    for n in range(1, degree + 1):
        derivative = func.diff(x, n)
        term = derivative.subs(x, center) / math.factorial(n)
        taylor_series.append(term * (values - center) ** n)
    return sum(taylor_series)

x = Symbol('x')
sin_func = sin(x)
values = np.arange(-5, 5, 0.1)
p_sin = np.sin(values)
t_sin4 = [taylor_approximation(sin_func, 0, 4, v) for v in values]
legends = ['sin(x)', 'Taylor 4 (quartic)']

fig, ax = plt.subplots()
ax.plot(values, p_sin, color='blue')
ax.plot(values, t_sin4, color='green')

ax.set_ylim([-5, 5])
ax.axhline(y=0.0, xmin=-5.0, xmax=5.0, color='black')
ax.axvline(x=0.0, ymin=-10.0, ymax=10.0, color='black')
ax.legend(legends)

plt.show()

# %%
import math
import numpy as np
import matplotlib.pyplot as plt
from sympy import Symbol, sin

def taylor_approximation(func, center, degree, values):
    x = Symbol('x')
    taylor_series = [func.subs(x, center)]
    for n in range(1, degree + 1):
        derivative = func.diff(x, n)
        term = derivative.subs(x, center) / math.factorial(n)
        taylor_series.append(term * (values - center) ** n)
    return sum(taylor_series)

values = np.arange(-5, 5, 0.1)
p_sin = np.sin(values)

x = Symbol('x')
sin_func = sin(x)
t_sin0 = [taylor_approximation(sin_func, 0, 0, v) for v in values]
t_sin1 = [taylor_approximation(sin_func, 0, 1, v) for v in values]
t_sin2 = [taylor_approximation(sin_func, 0, 2, v) for v in values]
t_sin3 = [taylor_approximation(sin_func, 0, 3, v) for v in values]
t_sin4 = [taylor_approximation(sin_func, 0, 4, v) for v in values]

legends = ['sin(x)', 'Taylor 0 (constant)', 'Taylor 1 (linear)', 'Taylor 2 (quadratic)', 'Taylor 3 (cubic)']

fig, ax = plt.subplots()
ax.plot(values, p_sin, color='red')
ax.plot(values, t_sin0, color='blue')
ax.plot(values, t_sin1, color='green')
ax.plot(values, t_sin2, color='orange')
ax.plot(values, t_sin3, color='purple')
ax.plot(values, t_sin4, color='yellow')

ax.set_ylim([-5, 5])
ax.axhline(y=0.0, xmin=-5.0, xmax=5.0, color='black')
ax.axvline(x=0.0, ymin=-10.0, ymax=10.0, color='black')
ax.legend(legends)

plt.show()
